# %%
from __future__ import division
import cympy
import cympy.rm
import pandas
import sys
sys.path.append("D:\\Users\\Jonathan\\Documents\\GitHub\\cymdist")
import function
import lookup

# Open a study
filename = 'C:\\Users\\emma\\Documents\\SCE Cymdist\\PIANO_20140718.sxst'
cympy.study.Open(filename)

# Retrieve microPMU data at t
udata = {'VMAG_A': 7287.4208984375,
         'VMAG_B': 7299.921875,
         'VMAG_C': 7318.2822265625,
         'P_A': 7272.5364248477308,
         'P_B': 2118.3817519608633,
         'P_C': 6719.1867010705246,
         'Q_A': -284.19075651498088,
         'Q_B': -7184.1189935099919,
         'Q_C': 3564.4269660296022,
         'units': ('kW', 'kVAR', 'V')}

# Set the downstream load and voltage and launch load allocation
function.load_allocation(udata)

# %%
# Run a power flow
lf = cympy.sim.LoadFlow()
lf.Run()

# %%
devices = function.list_devices()
temp = devices[devices.device_type == 'Underground type.'].device.tolist()
# Out:
# There are 1 Breaker type.
# There are 309 Switch type.
# There are 308 Underground type.
# There are 131 Spot Load type.
# There are 2 Shunt Capacitor type.

# %%
cympy.study.QueryInfoDevice("VpuA", temp[1].DeviceNumber, temp[1].DeviceType)
# Out:
# '0.923'

# %%
temp[1].DeviceNumber
# Out:
# 'BS1817-R$ND46806569'

# %%
temp[1].DeviceType
# Out:
# 10

# %%
voltage = function.get_voltage(devices[devices.device_type == 'Underground type.'])
# Out:
# > d:\users\jonathan\documents\github\cymdist\function.py(126)get_voltage()
# -> voltage.loc[device.Index, 'voltage_A'] = cympy.study.QueryInfoDevice(
# (Pdb) device.device_type_id
# 10
# (Pdb) n
# > d:\users\jonathan\documents\github\cymdist\function.py(127)get_voltage()
# -> "VpuA", device.device_number, device.device_type_id)
# (Pdb) n
# NotImplementedError: Wrong number or type of arguments for overloaded function 'QueryInfoDevice'.
#   Possible C/C++ prototypes are:
#     QueryInfoDevice(CYMString,CYMString,DeviceType::DeviceTypeEnum,int)
#     QueryInfoDevice(CYMString,CYMString,DeviceType::DeviceTypeEnum)
# > d:\users\jonathan\documents\github\cymdist\function.py(127)get_voltage()
# -> "VpuA", device.device_number, device.device_type_id)
# (Pdb) device.device_number
# 'ND46806418$BS1387-1'
# (Pdb) device.device_type_id
# 10
# (Pdb) type(device.device_type_id)
# <class 'numpy.int64'>
# (Pdb) int(device.device_type_id)
# 10
# (Pdb) type(int(device.device_type_id))
# <class 'int'>
# (Pdb) q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-6-3932b775691d> in <module>()
# ----> 1 voltage = function.get_voltage(devices[devices.device_type == 'Underground type.'])
#
# D:\Users\Jonathan\Documents\GitHub\cymdist\function.py in get_voltage(devices)
#     125             "VpuA", device.device_number, int(device.device_type_id))
#     126         voltage.loc[device.Index, 'voltage_B'] = cympy.study.QueryInfoDevice(
# --> 127             "VpuB", device.device_number, int(device.device_type_id))
#     128         voltage.loc[device.Index, 'voltage_C'] = cympy.study.QueryInfoDevice(
#     129             "VpuC", device.device_number, int(device.device_type_id))
#
# c:\python34\lib\bdb.py in trace_dispatch(self, frame, event, arg)
#      52             return self.dispatch_return(frame, arg)
#      53         if event == 'exception':
# ---> 54             return self.dispatch_exception(frame, arg)
#      55         if event == 'c_call':
#      56             return self.trace_dispatch
#
# c:\python34\lib\bdb.py in dispatch_exception(self, frame, arg)
#     108                     and arg[0] is StopIteration and arg[2] is None):
#     109                 self.user_exception(frame, arg)
# --> 110                 if self.quitting: raise BdbQuit
#     111         # Stop at the StopIteration or GeneratorExit exception when the user
#     112         # has set stopframe in a generator by issuing a return command, or a
#
# BdbQuit:

# %%
ab_high = cympy.study.ListAbnormalConditions(cympy.enums.AbnormalConditionType.HighVoltage)
ab_low = cympy.study.ListAbnormalConditions(cympy.enums.AbnormalConditionType.LowVoltage)

# %%
ab_low[0]
# Out:
# Type: 7, ID: 'PME3147-2$PMH3148-1', ItemType: 10

# %%
devices = function.list_devices()
# Out:
# There are 1 Breaker type.
# There are 309 Switch type.
# There are 308 Underground type.
# There are 131 Spot Load type.
# There are 2 Shunt Capacitor type.

# %%
# temp = devices[devices.device_number == 'PME3147-2$PMH3148-1'].device.tolist()
temp = devices[devices.device_type == 'Switch type.'].device.tolist()
# Out:
# There are 1 Breaker type.
# There are 309 Switch type.
# There are 308 Underground type.
# There are 131 Spot Load type.
# There are 2 Shunt Capacitor type.

# %%
function._describe_object(temp[0])
# Out:
# DeviceNumber
# Extensions
# Tags
# UserDefinedValues
# Instruments
# DeviceStage
# Flags
# DeviceID
# Location
# ClosedPhase
# AlternateGroundTripRating
# AlternatePhaseTripRating
# ConnectionStatus
# BypassOnRestoration
# TCCSettingID
# NormalFeedingNodeID
# GroundTripRating
# PhaseTripRating
# NormalStatus
# Strategic
# RestorationMode
# RemoteControlled
# Restriction
# UseAlternate
# Reversible
# SymbolSize
# Meter
# Position
# FaultIndicator
# Automated
# SensorMode

# %%
# temp[0].GetValue('EarthResistivity')
cympy.study.QueryInfoDevice("KVAA", temp[10].DeviceNumber, temp[10].DeviceType)
# Out:
# ''

# %%
nodes = cympy.study.ListNodes()

# %%
for value in cympy.dm.Describe(nodes[0].GetObjType()):
    print(value.Name)
# Out:
# NodeID
# ZoneID
# UserDefinedBaseVoltage
# Connectors
# BusDisplay
# ArcFlashNode
# OptimalPowerFlowNode
# UserDefinedValues
# Instruments
# LimitsNode
# Tag

# %%
nodes[0].GetValue("Connectors")
# Out:
# '1'

# %%
devices = function.list_devices()
devices
# Out:
# There are 1 Breaker type.
# There are 309 Switch type.
# There are 308 Underground type.
# There are 131 Spot Load type.
# There are 2 Shunt Capacitor type.
#                                                 device  device_type_id  \
# 0       (DeviceNumber: 'BREAKER_14036', DeviceType: 2)               2
# 1          (DeviceNumber: 'B5082372-1', DeviceType: 6)               6
# 2           (DeviceNumber: '173194021', DeviceType: 6)               6
# 3    (DeviceNumber: '60135717_14036$GS5020-1_14036-...               6
# 4    (DeviceNumber: '46790016_14036$J605A-3P_14036-...               6
# 5            (DeviceNumber: 'BS1817-T', DeviceType: 6)               6
# 6          (DeviceNumber: 'B5082373-1', DeviceType: 6)               6
# 7    (DeviceNumber: '168994773_14036$J833A-3P_14036...               6
# 8          (DeviceNumber: 'B5082841-1', DeviceType: 6)               6
# 9           (DeviceNumber: 'RCS2825-1', DeviceType: 6)               6
# 10   (DeviceNumber: '168994781_14036$J833A-2_F_1403...               6
# 11         (DeviceNumber: 'B5143828-2', DeviceType: 6)               6
# 12          (DeviceNumber: 'PME3832-2', DeviceType: 6)               6
# 13         (DeviceNumber: 'B5142861-2', DeviceType: 6)               6
# 14   (DeviceNumber: '166521444_14036$J366A-1P_14036...               6
# 15   (DeviceNumber: '46733331_14036$GS0352-6_14036-...               6
# 16   (DeviceNumber: 'GS2833-1_14036$46788452_14036-...               6
# 17         (DeviceNumber: 'B5143829-2', DeviceType: 6)               6
# 18         (DeviceNumber: 'B5142850-2', DeviceType: 6)               6
# 19         (DeviceNumber: 'B5142862-2', DeviceType: 6)               6
# 20   (DeviceNumber: '46790674_14036$J889A-4P_14036-...               6
# 21         (DeviceNumber: 'P5491572-1', DeviceType: 6)               6
# 22         (DeviceNumber: 'P5593789-2', DeviceType: 6)               6
# 23          (DeviceNumber: 'PME3146-4', DeviceType: 6)               6
# 24         (DeviceNumber: 'B5142863-2', DeviceType: 6)               6
# 25   (DeviceNumber: 'OS2959-1_14036$46734184_14036-...               6
# 26         (DeviceNumber: 'P5083156-A', DeviceType: 6)               6
# 27          (DeviceNumber: '165605994', DeviceType: 6)               6
# 28           (DeviceNumber: 'BS2834-1', DeviceType: 6)               6
# 29         (DeviceNumber: 'B5142854-2', DeviceType: 6)               6
# ..                                                 ...             ...
# 721         (DeviceNumber: 'B5350429', DeviceType: 14)              14
# 722         (DeviceNumber: 'P5491624', DeviceType: 14)              14
# 723         (DeviceNumber: 'P5593789', DeviceType: 14)              14
# 724         (DeviceNumber: 'P5335190', DeviceType: 14)              14
# 725         (DeviceNumber: 'B5350422', DeviceType: 14)              14
# 726  (DeviceNumber: 'UNSET_14036$UNSET_T_14036-1', ...              14
# 727         (DeviceNumber: 'B5082372', DeviceType: 14)              14
# 728         (DeviceNumber: 'B5125254', DeviceType: 14)              14
# 729         (DeviceNumber: 'P5083156', DeviceType: 14)              14
# 730         (DeviceNumber: 'B5082458', DeviceType: 14)              14
# 731         (DeviceNumber: 'B5350572', DeviceType: 14)              14
# 732         (DeviceNumber: 'V5085916', DeviceType: 14)              14
# 733         (DeviceNumber: 'B5142855', DeviceType: 14)              14
# 734         (DeviceNumber: 'P5204143', DeviceType: 14)              14
# 735         (DeviceNumber: 'P5083021', DeviceType: 14)              14
# 736         (DeviceNumber: 'B5207537', DeviceType: 14)              14
# 737         (DeviceNumber: 'B5142774', DeviceType: 14)              14
# 738       (DeviceNumber: 'V5081928PT', DeviceType: 14)              14
# 739        (DeviceNumber: 'J889A-1PT', DeviceType: 14)              14
# 740         (DeviceNumber: 'B5082445', DeviceType: 14)              14
# 741         (DeviceNumber: 'B5330535', DeviceType: 14)              14
# 742         (DeviceNumber: 'B5144574', DeviceType: 14)              14
# 743         (DeviceNumber: 'B5082842', DeviceType: 14)              14
# 744         (DeviceNumber: 'B5142781', DeviceType: 14)              14
# 745         (DeviceNumber: 'V5081511', DeviceType: 14)              14
# 746         (DeviceNumber: 'B5350428', DeviceType: 14)              14
# 747         (DeviceNumber: 'P5206828', DeviceType: 14)              14
# 748         (DeviceNumber: 'P5085437', DeviceType: 14)              14
# 749         (DeviceNumber: 'P5204144', DeviceType: 16)              16
# 750         (DeviceNumber: 'P5206829', DeviceType: 16)              16
#
#                         device_number            device_type
# 0                       BREAKER_14036          Breaker type.
# 1                          B5082372-1           Switch type.
# 2                           173194021           Switch type.
# 3     60135717_14036$GS5020-1_14036-1           Switch type.
# 4     46790016_14036$J605A-3P_14036-1           Switch type.
# 5                            BS1817-T           Switch type.
# 6                          B5082373-1           Switch type.
# 7    168994773_14036$J833A-3P_14036-1           Switch type.
# 8                          B5082841-1           Switch type.
# 9                           RCS2825-1           Switch type.
# 10   168994781_14036$J833A-2_F_1403-1           Switch type.
# 11                         B5143828-2           Switch type.
# 12                          PME3832-2           Switch type.
# 13                         B5142861-2           Switch type.
# 14   166521444_14036$J366A-1P_14036-1           Switch type.
# 15    46733331_14036$GS0352-6_14036-1           Switch type.
# 16    GS2833-1_14036$46788452_14036-1           Switch type.
# 17                         B5143829-2           Switch type.
# 18                         B5142850-2           Switch type.
# 19                         B5142862-2           Switch type.
# 20    46790674_14036$J889A-4P_14036-1           Switch type.
# 21                         P5491572-1           Switch type.
# 22                         P5593789-2           Switch type.
# 23                          PME3146-4           Switch type.
# 24                         B5142863-2           Switch type.
# 25    OS2959-1_14036$46734184_14036-1           Switch type.
# 26                         P5083156-A           Switch type.
# 27                          165605994           Switch type.
# 28                           BS2834-1           Switch type.
# 29                         B5142854-2           Switch type.
# ..                                ...                    ...
# 721                          B5350429        Spot Load type.
# 722                          P5491624        Spot Load type.
# 723                          P5593789        Spot Load type.
# 724                          P5335190        Spot Load type.
# 725                          B5350422        Spot Load type.
# 726       UNSET_14036$UNSET_T_14036-1        Spot Load type.
# 727                          B5082372        Spot Load type.
# 728                          B5125254        Spot Load type.
# 729                          P5083156        Spot Load type.
# 730                          B5082458        Spot Load type.
# 731                          B5350572        Spot Load type.
# 732                          V5085916        Spot Load type.
# 733                          B5142855        Spot Load type.
# 734                          P5204143        Spot Load type.
# 735                          P5083021        Spot Load type.
# 736                          B5207537        Spot Load type.
# 737                          B5142774        Spot Load type.
# 738                        V5081928PT        Spot Load type.
# 739                         J889A-1PT        Spot Load type.
# 740                          B5082445        Spot Load type.
# 741                          B5330535        Spot Load type.
# 742                          B5144574        Spot Load type.
# 743                          B5082842        Spot Load type.
# 744                          B5142781        Spot Load type.
# 745                          V5081511        Spot Load type.
# 746                          B5350428        Spot Load type.
# 747                          P5206828        Spot Load type.
# 748                          P5085437        Spot Load type.
# 749                          P5204144  Shunt Capacitor type.
# 750                          P5206829  Shunt Capacitor type.
#
# [751 rows x 4 columns]

# %%
a = devices[devices.device_type == 'Underground type.']
de = function.get_device(a.ix[310].device_number, a.ix[310].device.DeviceType)
for value in cympy.dm.Describe(de.GetObjType()):
    print(value.Name)
# Out:
# [(Name: 'DeviceNumber', Type: ''), (Name: 'Extensions', Type: 'DeviceExtensions'), (Name: 'Tags', Type: 'Tags'), (Name: 'UserDefinedValues', Type: 'UserDefinedValues'), (Name: 'Instruments', Type: 'Instruments'), (Name: 'DeviceStage', Type: ''), (Name: 'Flags', Type: ''), (Name: 'Length', Type: ''), (Name: 'Position', Type: 'Point'), (Name: 'ConnectionStatus', Type: 'ConnectionStatus'), (Name: 'HarmonicModel', Type: 'LineHarmonicModel'), (Name: 'TCCSettings', Type: 'TCCLineConfigurationSettings'), (Name: 'TCCDisplaySettings', Type: 'TCCLineConfigurationDisplaySettings'), (Name: 'CableID', Type: ''), (Name: 'NumberOfCableInParallel', Type: ''), (Name: 'NominalRating_Amps', Type: ''), (Name: 'FirstRating', Type: ''), (Name: 'SecondRating', Type: ''), (Name: 'ThirdRating', Type: ''), (Name: 'FourthRating', Type: ''), (Name: 'AmpacityDeratingFactor', Type: ''), (Name: 'EarthResistivity', Type: ''), (Name: 'OperatingTemperature', Type: ''), (Name: 'Height', Type: ''), (Name: 'DistanceBetweenConductors', Type: ''), (Name: 'BondingType', Type: 'CableSheathBondingType'), (Name: 'CableConfiguration', Type: 'CableConfiguration'), (Name: 'DuctMaterial', Type: 'CableDuctMaterial'), (Name: 'CustomPoints', Type: 'Points'), (Name: 'Bundled', Type: ''), (Name: 'Neutral1ID', Type: ''), (Name: 'Neutral2ID', Type: ''), (Name: 'Neutral3ID', Type: ''), (Name: 'Neutral1Type', Type: 'EquipmentDBType'), (Name: 'Neutral2Type', Type: 'EquipmentDBType'), (Name: 'Neutral3Type', Type: 'EquipmentDBType'), (Name: 'OptimalPowerFlowModel', Type: 'LineConfigurationExtOPF')]
# DeviceNumber
# Extensions
# Tags
# UserDefinedValues
# Instruments
# DeviceStage
# Flags
# Length
# Position
# ConnectionStatus
# HarmonicModel
# TCCSettings
# TCCDisplaySettings
# CableID
# NumberOfCableInParallel
# NominalRating_Amps
# FirstRating
# SecondRating
# ThirdRating
# FourthRating
# AmpacityDeratingFactor
# EarthResistivity
# OperatingTemperature
# Height
# DistanceBetweenConductors
# BondingType
# CableConfiguration
# DuctMaterial
# CustomPoints
# Bundled
# Neutral1ID
# Neutral2ID
# Neutral3ID
# Neutral1Type
# Neutral2Type
# Neutral3Type
# OptimalPowerFlowModel

# %%
a
# Out:
#                                                 device  device_type_id  \
# 310  (DeviceNumber: 'ND46806418$BS1387-1', DeviceTy...              10
# 311  (DeviceNumber: 'BS1817-R$ND46806569', DeviceTy...              10
# 312  (DeviceNumber: 'ND46806165$ND170173175', Devic...              10
# 313  (DeviceNumber: 'B5082371-1$B5082842-2', Device...              10
# 314  (DeviceNumber: 'B5144573-2$BS2181-1', DeviceTy...              10
# 315  (DeviceNumber: '165606021$B5350424-1', DeviceT...              10
# 316  (DeviceNumber: 'PME3832-4$PME3832-3', DeviceTy...              10
# 317  (DeviceNumber: 'B5082841-1$B5082372-2', Device...              10
# 318  (DeviceNumber: 'ND165289409$B5082371-2', Devic...              10
# 319  (DeviceNumber: 'ND144224025$B5207537-1', Devic...              10
# 320  (DeviceNumber: '152874903$P5576800-1', DeviceT...              10
# 321  (DeviceNumber: 'B5141886-2$ND46805528', Device...              10
# 322  (DeviceNumber: 'B5082457-2$B5082458-2', Device...              10
# 323  (DeviceNumber: 'B5142852-1$ND46806276', Device...              10
# 324  (DeviceNumber: '46734184$OS2959-2', DeviceType...              10
# 325  (DeviceNumber: 'OS0346-4$46677525', DeviceType...              10
# 326  (DeviceNumber: 'B5125000-2$B5125256-1', Device...              10
# 327  (DeviceNumber: 'RCS2825-2$46753145', DeviceTyp...              10
# 328  (DeviceNumber: 'ND46807195$ND46806615', Device...              10
# 329  (DeviceNumber: 'BS2723-1$B5144527-1', DeviceTy...              10
# 330  (DeviceNumber: 'ND170173104$BS2181-1', DeviceT...              10
# 331  (DeviceNumber: 'B5350425-2$B5350426-2', Device...              10
# 332  (DeviceNumber: 'RCS2825-2$V5081928T1', DeviceT...              10
# 333  (DeviceNumber: 'P5373259-2$P5373260-2', Device...              10
# 334  (DeviceNumber: 'BS1817-L$ND170173094', DeviceT...              10
# 335  (DeviceNumber: 'BS1444-1$ND46807195', DeviceTy...              10
# 336  (DeviceNumber: 'J889A-3P$ND150260779', DeviceT...              10
# 337  (DeviceNumber: 'J833A-1P$J848A-3P', DeviceType...              10
# 338  (DeviceNumber: 'ND150260779$173193980', Device...              10
# 339  (DeviceNumber: 'BS2827-1$ND46805586', DeviceTy...              10
# ..                                                 ...             ...
# 588  (DeviceNumber: 'B5206655-2$ND166461146', Devic...              10
# 589  (DeviceNumber: 'BS2834-1$P5083289-B', DeviceTy...              10
# 590  (DeviceNumber: 'B5082458-1$B5082459-1', Device...              10
# 591  (DeviceNumber: 'BS1384-1$ND46806714', DeviceTy...              10
# 592  (DeviceNumber: '141096551$P5206725-A', DeviceT...              10
# 593  (DeviceNumber: 'P5373262-2$167136750', DeviceT...              10
# 594  (DeviceNumber: 'B5144527-2$ND144224025', Devic...              10
# 595  (DeviceNumber: 'ND151688013$V5335195PT', Devic...              10
# 596  (DeviceNumber: 'P5491572-2$46789097', DeviceTy...              10
# 597  (DeviceNumber: 'B5142602-1$ND46807195', Device...              10
# 598  (DeviceNumber: '46733306$46733291', DeviceType...              10
# 599  (DeviceNumber: 'ND46806843$B5142850-2', Device...              10
# 600  (DeviceNumber: 'B5187886-2$ND170173200', Devic...              10
# 601  (DeviceNumber: 'ND170173200$BS2038-1', DeviceT...              10
# 602  (DeviceNumber: '150101290$P5083156-B', DeviceT...              10
# 603  (DeviceNumber: '46733323$46733331', DeviceType...              10
# 604  (DeviceNumber: '167663838$P5083019-A', DeviceT...              10
# 605  (DeviceNumber: 'ND164593160$V5084149', DeviceT...              10
# 606  (DeviceNumber: '168994765$168994781', DeviceTy...              10
# 607  (DeviceNumber: '46790666$46790674', DeviceType...              10
# 608  (DeviceNumber: 'BS2102-R$46678093', DeviceType...              10
# 609  (DeviceNumber: 'GS0352-3$ND151688013', DeviceT...              10
# 610  (DeviceNumber: 'J366A-1P$B5330562-1', DeviceTy...              10
# 611  (DeviceNumber: 'ND170172955$164247330', Device...              10
# 612  (DeviceNumber: 'RCS2825-4$ND46805964', DeviceT...              10
# 613  (DeviceNumber: 'ND46806569$165605994', DeviceT...              10
# 614  (DeviceNumber: '150101213$P5593789-1', DeviceT...              10
# 615  (DeviceNumber: 'ND46807143$P5335190', DeviceTy...              10
# 616  (DeviceNumber: 'P5083018-B$167663838', DeviceT...              10
# 617  (DeviceNumber: 'PME3832-3$165606021', DeviceTy...              10
#
#               device_number        device_type
# 310     ND46806418$BS1387-1  Underground type.
# 311     BS1817-R$ND46806569  Underground type.
# 312  ND46806165$ND170173175  Underground type.
# 313   B5082371-1$B5082842-2  Underground type.
# 314     B5144573-2$BS2181-1  Underground type.
# 315    165606021$B5350424-1  Underground type.
# 316     PME3832-4$PME3832-3  Underground type.
# 317   B5082841-1$B5082372-2  Underground type.
# 318  ND165289409$B5082371-2  Underground type.
# 319  ND144224025$B5207537-1  Underground type.
# 320    152874903$P5576800-1  Underground type.
# 321   B5141886-2$ND46805528  Underground type.
# 322   B5082457-2$B5082458-2  Underground type.
# 323   B5142852-1$ND46806276  Underground type.
# 324       46734184$OS2959-2  Underground type.
# 325       OS0346-4$46677525  Underground type.
# 326   B5125000-2$B5125256-1  Underground type.
# 327      RCS2825-2$46753145  Underground type.
# 328   ND46807195$ND46806615  Underground type.
# 329     BS2723-1$B5144527-1  Underground type.
# 330    ND170173104$BS2181-1  Underground type.
# 331   B5350425-2$B5350426-2  Underground type.
# 332    RCS2825-2$V5081928T1  Underground type.
# 333   P5373259-2$P5373260-2  Underground type.
# 334    BS1817-L$ND170173094  Underground type.
# 335     BS1444-1$ND46807195  Underground type.
# 336    J889A-3P$ND150260779  Underground type.
# 337       J833A-1P$J848A-3P  Underground type.
# 338   ND150260779$173193980  Underground type.
# 339     BS2827-1$ND46805586  Underground type.
# ..                      ...                ...
# 588  B5206655-2$ND166461146  Underground type.
# 589     BS2834-1$P5083289-B  Underground type.
# 590   B5082458-1$B5082459-1  Underground type.
# 591     BS1384-1$ND46806714  Underground type.
# 592    141096551$P5206725-A  Underground type.
# 593    P5373262-2$167136750  Underground type.
# 594  B5144527-2$ND144224025  Underground type.
# 595  ND151688013$V5335195PT  Underground type.
# 596     P5491572-2$46789097  Underground type.
# 597   B5142602-1$ND46807195  Underground type.
# 598       46733306$46733291  Underground type.
# 599   ND46806843$B5142850-2  Underground type.
# 600  B5187886-2$ND170173200  Underground type.
# 601    ND170173200$BS2038-1  Underground type.
# 602    150101290$P5083156-B  Underground type.
# 603       46733323$46733331  Underground type.
# 604    167663838$P5083019-A  Underground type.
# 605    ND164593160$V5084149  Underground type.
# 606     168994765$168994781  Underground type.
# 607       46790666$46790674  Underground type.
# 608       BS2102-R$46678093  Underground type.
# 609    GS0352-3$ND151688013  Underground type.
# 610     J366A-1P$B5330562-1  Underground type.
# 611   ND170172955$164247330  Underground type.
# 612    RCS2825-4$ND46805964  Underground type.
# 613    ND46806569$165605994  Underground type.
# 614    150101213$P5593789-1  Underground type.
# 615     ND46807143$P5335190  Underground type.
# 616    P5083018-B$167663838  Underground type.
# 617     PME3832-3$165606021  Underground type.
#
# [308 rows x 4 columns]

# %%
function.get_device(devices.ix[0].device_number, devices.ix[0].device.DeviceType)
# Out:
# [(Name: 'DeviceNumber', Type: ''), (Name: 'Extensions', Type: 'DeviceExtensions'), (Name: 'Tags', Type: 'Tags'), (Name: 'UserDefinedValues', Type: 'UserDefinedValues'), (Name: 'Instruments', Type: 'Instruments'), (Name: 'DeviceStage', Type: ''), (Name: 'Flags', Type: ''), (Name: 'DeviceID', Type: ''), (Name: 'Location', Type: 'Location'), (Name: 'ClosedPhase', Type: 'Phase'), (Name: 'AlternateGroundTripRating', Type: ''), (Name: 'AlternatePhaseTripRating', Type: ''), (Name: 'ConnectionStatus', Type: 'ConnectionStatus'), (Name: 'BypassOnRestoration', Type: ''), (Name: 'TCCSettingID', Type: ''), (Name: 'NormalFeedingNodeID', Type: ''), (Name: 'GroundTripRating', Type: ''), (Name: 'PhaseTripRating', Type: ''), (Name: 'NormalStatus', Type: 'SwitchStatus'), (Name: 'Strategic', Type: ''), (Name: 'RestorationMode', Type: 'RestorationMode'), (Name: 'RemoteControlled', Type: ''), (Name: 'Restriction', Type: ''), (Name: 'UseAlternate', Type: ''), (Name: 'Reversible', Type: ''), (Name: 'SymbolSize', Type: ''), (Name: 'Meter', Type: 'Meter'), (Name: 'Position', Type: 'Point'), (Name: 'FaultIndicator', Type: 'FaultIndicatorType'), (Name: 'EnableFuseSaving', Type: ''), (Name: 'MinRatedCurrentForFuseSaving', Type: ''), (Name: 'Automated', Type: ''), (Name: 'SensorMode', Type: 'SensorMode'), (Name: 'EnableReclosing', Type: ''), (Name: 'Speed', Type: ''), (Name: 'SeqOpFirstPhase', Type: ''), (Name: 'SeqOpFirstGround', Type: ''), (Name: 'SeqOpLockoutPhase', Type: ''), (Name: 'SeqOpLockoutGround', Type: ''), (Name: 'SeqResetTime', Type: ''), (Name: 'SeqReclosingTime1', Type: ''), (Name: 'SeqReclosingTime2', Type: ''), (Name: 'SeqReclosingTime3', Type: '')]
# (DeviceNumber: 'BREAKER_14036', DeviceType: 2)

# %%
networks = cympy.study.ListNetworks()

# %%
networks
# Out:
# ['PIANO_12KV']

# %%
devices[devices.device_type == 'Shunt Capacitor type.']
# Out:
#                                          device  device_type_id device_number  \
# 749  (DeviceNumber: 'P5204144', DeviceType: 16)              16      P5204144
# 750  (DeviceNumber: 'P5206829', DeviceType: 16)              16      P5206829
#
#                device_type
# 749  Shunt Capacitor type.
# 750  Shunt Capacitor type.

# %%
function._describe_object(devices.ix[749].device)
# Out:
# DeviceNumber
# Extensions
# Tags
# UserDefinedValues
# Instruments
# DeviceStage
# Flags
# DeviceID
# Location
# ConnectionStatus
# ConnectionConfiguration
# CTConnection
# FixedKVARA
# FixedKVARB
# FixedKVARC
# FixedLossesA
# FixedLossesB
# FixedLossesC
# ByPhase
# KVLN
# InterruptingRating
# SymbolSize
# SwitchedKVARA
# SwitchedKVARB
# SwitchedKVARC
# SwitchedLossesA_KW
# SwitchedLossesB_KW
# SwitchedLossesC_KW
# CapacitorControl
# LongTermDynamicsModel
# VoltageOverride
# VoltageOverrideOn
# VoltageOverrideOff
# VoltageOverrideDeadband

# %%
devices.ix[749].device.CapacitorControl
# Question is how to set CapacitorControl to something different like VoltageControlled
# In network properties / Equivalent there is a field for source equivalent voltage
# How do I change the properties for phases A, B and C Where do I find the equivalent
# Out:
# -------------------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-7-578adaf481eb> in <module>()
# ----> 1 devices.ix[749].device.CapacitorControl
#
# C:\Program Files (x86)\CYME\cympy\dm.py in <lambda>(self, name)
#     377     __swig_getmethods__ = {}
#     378     for _s in [_CymPyDataObj]: __swig_getmethods__.update(getattr(_s,'__swig_getmethods__',{}))
# --> 379     __getattr__ = lambda self, name: _swig_getattr(self, Device, name)
#     380     __repr__ = _swig_repr
#     381     def __init__(self):
#
# C:\Program Files (x86)\CYME\cympy\dm.py in _swig_getattr(self, class_type, name)
#      68     method = class_type.__swig_getmethods__.get(name,None)
#      69     if method: return method(self)
# ---> 70     raise AttributeError(name)
#      71
#      72 def _swig_repr(self):
#
# AttributeError: CapacitorControl

# %%
cympy.enums.ControlType.VoltageControlled
# Out:
# -------------------------
# TypeErrorTraceback (most recent call last)
# <ipython-input-11-a3ad12ca7a5b> in <module>()
#       1
# ----> 2 cympy.enums.__dict__()
#
# TypeError: 'dict' object is not callable
